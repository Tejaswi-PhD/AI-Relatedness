# %%
from sec_edgar_downloader import Downloader
import pandas as pd
import os

# %%
# -*- coding: utf-8 -*-
"""
Download 10-K HTML filings for firms in cik_list.csv
for 2017–2024 using sec-edgar-downloader.
"""

import pandas as pd
import os
from sec_edgar_downloader import Downloader
from time import sleep
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# Get the current working directory (where the script is located)
cwd = os.getcwd()

# Define output directory for HTML filings
output_dir = os.path.join(cwd, "10k_html_filings_2017_2024") # Changed name slightly for clarity
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# --- MODIFIED SECTION: Load CIK Data ---
input_cik_file = "cik_list.xlsx"
try:
    # Assuming the column name in your CSV is 'cik' (lowercase) as specified.
    # If it's 'CIK' (uppercase), change 'cik' to 'CIK' below.
    cik_data = pd.read_excel(input_cik_file)
    if 'cik' not in cik_data.columns:
        # Try to find a CIK-like column if 'cik' is not present
        potential_cik_cols = [col for col in cik_data.columns if 'cik' in col.lower()]
        if potential_cik_cols:
            cik_column_name = potential_cik_cols[0]
            print(f"Info: Using column '{cik_column_name}' from '{input_cik_file}' for CIKs.")
        else:
            raise ValueError(f"Error: Column 'cik' not found in '{input_cik_file}'. Please ensure your CSV has a column named 'cik'. Found columns: {cik_data.columns.tolist()}")
    else:
        cik_column_name = 'cik'

except FileNotFoundError:
    print(f"Error: The file '{input_cik_file}' was not found in the current directory: {cwd}")
    print("Please create this file with a single column named 'cik' containing the CIK numbers.")
    exit()
except Exception as e:
    print(f"Error reading '{input_cik_file}': {e}")
    exit()

# Ensure CIK is a string and padded with zeros to 10 digits (SEC format)
# Also remove any non-numeric characters and convert to int first to handle potential floats like "12345.0"
try:
    cik_data['CIK_formatted'] = cik_data[cik_column_name].astype(str).str.replace(r'\.0$', '', regex=True).str.zfill(10)
except AttributeError as e:
    print(f"Error processing CIK column '{cik_column_name}'. Are you sure it contains CIK numbers? Error: {e}")
    exit()


print(f"Total CIKs to process from '{input_cik_file}': {len(cik_data['CIK_formatted'].unique())}")
print("Sample CIKs (first 5):")
print(cik_data['CIK_formatted'].head())
# --- END MODIFIED SECTION ---

## Change the username and email address below in the Downloader initialization


dl = Downloader(
    company_name="Tejaswi Kalaga", 
    email_address="kalagat23@iimb.ac.in",   
    download_folder=output_dir
)


total_downloaded = 0
failed_ciks = []


for cik_value in cik_data['CIK_formatted'].unique():
    try:
        print(f"Downloading 10-K filings for CIK {cik_value} from 2017 to 2024")
        num_downloaded = dl.get(
            "10-K",
            cik_value,       # Use CIK directly
            after="2017-01-01", # New start date
            before="2024-12-31",# New end date (inclusive)
            download_details=True
        )
        print(f"Download completed for CIK {cik_value}. Number of filings downloaded: {num_downloaded}")
        total_downloaded += num_downloaded
        sleep(1)  # Delay to avoid rate limiting (SEC allows 10 requests/second)
    except Exception as e:
        print(f"Error downloading 10-K for CIK {cik_value}: {e}")
        failed_ciks.append(cik_value)
        sleep(1)  # Delay to avoid rate limiting set by EDGAR for bulk downloads


print("\n--- Download Summary ---")
print(f"Finished downloading 10-K HTML filings.")
print(f"Total filings downloaded: {total_downloaded}")
print(f"Files are saved in {output_dir}")

if failed_ciks:
    print(f"\nFailed to download for the following CIKs ({len(failed_ciks)}):")
    for fcik in failed_ciks:
        print(f"- {fcik}")
else:
    print("\nAll CIKs processed successfully (though some may not have had filings in the period).")
# Out:
# Total CIKs to process from 'cik_list.xlsx': 487
# Sample CIKs (first 5):
# 0    0000001800
# 1    0000002488
# 2    0000004962
# 3    0000004977
# 4    0000005272
# Name: CIK_formatted, dtype: object
# Downloading 10-K filings for CIK 0000001800 from 2017 to 2024
# Download completed for CIK 0000001800. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000002488 from 2017 to 2024
# Download completed for CIK 0000002488. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000004962 from 2017 to 2024
# Download completed for CIK 0000004962. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000004977 from 2017 to 2024
# Download completed for CIK 0000004977. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000005272 from 2017 to 2024
# Download completed for CIK 0000005272. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000006201 from 2017 to 2024
# Download completed for CIK 0000006201. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000006885 from 2017 to 2024
# Download completed for CIK 0000006885. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0000007084 from 2017 to 2024
# Download completed for CIK 0000007084. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000010329 from 2017 to 2024
# Download completed for CIK 0000010329. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000014272 from 2017 to 2024
# Download completed for CIK 0000014272. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000014693 from 2017 to 2024
# Download completed for CIK 0000014693. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000014707 from 2017 to 2024
# Download completed for CIK 0000014707. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000016099 from 2017 to 2024
# Download completed for CIK 0000016099. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0000016732 from 2017 to 2024
# Download completed for CIK 0000016732. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000016918 from 2017 to 2024
# Download completed for CIK 0000016918. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000016988 from 2017 to 2024
# Download completed for CIK 0000016988. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000018230 from 2017 to 2024
# Download completed for CIK 0000018230. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000018255 from 2017 to 2024
# Download completed for CIK 0000018255. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000018498 from 2017 to 2024
# Download completed for CIK 0000018498. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000018926 from 2017 to 2024
# Download completed for CIK 0000018926. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000019612 from 2017 to 2024
# Download completed for CIK 0000019612. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0000019617 from 2017 to 2024
# Download completed for CIK 0000019617. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000020171 from 2017 to 2024
# Download completed for CIK 0000020171. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000021076 from 2017 to 2024
# Download completed for CIK 0000021076. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000021175 from 2017 to 2024
# Download completed for CIK 0000021175. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000021344 from 2017 to 2024
# Download completed for CIK 0000021344. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000021665 from 2017 to 2024
# Download completed for CIK 0000021665. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000022356 from 2017 to 2024
# Download completed for CIK 0000022356. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000023217 from 2017 to 2024
# Download completed for CIK 0000023217. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000024491 from 2017 to 2024
# Download completed for CIK 0000024491. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0000024545 from 2017 to 2024
# Download completed for CIK 0000024545. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000027419 from 2017 to 2024
# Download completed for CIK 0000027419. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000027904 from 2017 to 2024
# Download completed for CIK 0000027904. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000028412 from 2017 to 2024
# Download completed for CIK 0000028412. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000028917 from 2017 to 2024
# Download completed for CIK 0000028917. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000029534 from 2017 to 2024
# Download completed for CIK 0000029534. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000030697 from 2017 to 2024
# Download completed for CIK 0000030697. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000031235 from 2017 to 2024
# Download completed for CIK 0000031235. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000032604 from 2017 to 2024
# Download completed for CIK 0000032604. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000033185 from 2017 to 2024
# Download completed for CIK 0000033185. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000034088 from 2017 to 2024
# Download completed for CIK 0000034088. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000034563 from 2017 to 2024
# Download completed for CIK 0000034563. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000035527 from 2017 to 2024
# Download completed for CIK 0000035527. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000036104 from 2017 to 2024
# Download completed for CIK 0000036104. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000036270 from 2017 to 2024
# Download completed for CIK 0000036270. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000036966 from 2017 to 2024
# Download completed for CIK 0000036966. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000037996 from 2017 to 2024
# Download completed for CIK 0000037996. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000038777 from 2017 to 2024
# Download completed for CIK 0000038777. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000039911 from 2017 to 2024
# Download completed for CIK 0000039911. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000040704 from 2017 to 2024
# Download completed for CIK 0000040704. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000040729 from 2017 to 2024
# Download completed for CIK 0000040729. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000040987 from 2017 to 2024
# Download completed for CIK 0000040987. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000042582 from 2017 to 2024
# Download completed for CIK 0000042582. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000046080 from 2017 to 2024
# Download completed for CIK 0000046080. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000047111 from 2017 to 2024
# Download completed for CIK 0000047111. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000047217 from 2017 to 2024
# Download completed for CIK 0000047217. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000048465 from 2017 to 2024
# Download completed for CIK 0000048465. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000049071 from 2017 to 2024
# Download completed for CIK 0000049071. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000049196 from 2017 to 2024
# Download completed for CIK 0000049196. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000049754 from 2017 to 2024
# Download completed for CIK 0000049754. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000050863 from 2017 to 2024
# Download completed for CIK 0000050863. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000051143 from 2017 to 2024
# Download completed for CIK 0000051143. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000055067 from 2017 to 2024
# Download completed for CIK 0000055067. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000055785 from 2017 to 2024
# Download completed for CIK 0000055785. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000056873 from 2017 to 2024
# Download completed for CIK 0000056873. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000057131 from 2017 to 2024
# Download completed for CIK 0000057131. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000059478 from 2017 to 2024
# Download completed for CIK 0000059478. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000059558 from 2017 to 2024
# Download completed for CIK 0000059558. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000060667 from 2017 to 2024
# Download completed for CIK 0000060667. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000062996 from 2017 to 2024
# Download completed for CIK 0000062996. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000063276 from 2017 to 2024
# Download completed for CIK 0000063276. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000063754 from 2017 to 2024
# Download completed for CIK 0000063754. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000063908 from 2017 to 2024
# Download completed for CIK 0000063908. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000064803 from 2017 to 2024
# Download completed for CIK 0000064803. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000064996 from 2017 to 2024
# Download completed for CIK 0000064996. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000065011 from 2017 to 2024
# Download completed for CIK 0000065011. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0000066382 from 2017 to 2024
# Download completed for CIK 0000066382. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000066740 from 2017 to 2024
# Download completed for CIK 0000066740. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000067088 from 2017 to 2024
# Download completed for CIK 0000067088. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000068505 from 2017 to 2024
# Download completed for CIK 0000068505. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000069733 from 2017 to 2024
# Download completed for CIK 0000069733. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000069891 from 2017 to 2024
# Download completed for CIK 0000069891. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000070858 from 2017 to 2024
# Download completed for CIK 0000070858. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000071691 from 2017 to 2024
# Download completed for CIK 0000071691. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000072333 from 2017 to 2024
# Download completed for CIK 0000072333. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000072573 from 2017 to 2024
# Download completed for CIK 0000072573. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000072971 from 2017 to 2024
# Download completed for CIK 0000072971. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000077476 from 2017 to 2024
# Download completed for CIK 0000077476. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000078003 from 2017 to 2024
# Download completed for CIK 0000078003. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000078239 from 2017 to 2024
# Download completed for CIK 0000078239. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000080424 from 2017 to 2024
# Download completed for CIK 0000080424. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000080661 from 2017 to 2024
# Download completed for CIK 0000080661. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000084129 from 2017 to 2024
# Download completed for CIK 0000084129. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0000084839 from 2017 to 2024
# Download completed for CIK 0000084839. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000086312 from 2017 to 2024
# Download completed for CIK 0000086312. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000089800 from 2017 to 2024
# Download completed for CIK 0000089800. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000091388 from 2017 to 2024
# Download completed for CIK 0000091388. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000091419 from 2017 to 2024
# Download completed for CIK 0000091419. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000091576 from 2017 to 2024
# Download completed for CIK 0000091576. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000092230 from 2017 to 2024
# Download completed for CIK 0000092230. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000092380 from 2017 to 2024
# Download completed for CIK 0000092380. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000093410 from 2017 to 2024
# Download completed for CIK 0000093410. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000093751 from 2017 to 2024
# Download completed for CIK 0000093751. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000094845 from 2017 to 2024
# Download completed for CIK 0000094845. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000097476 from 2017 to 2024
# Download completed for CIK 0000097476. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000098246 from 2017 to 2024
# Download completed for CIK 0000098246. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0000100493 from 2017 to 2024
# Download completed for CIK 0000100493. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000100517 from 2017 to 2024
# Download completed for CIK 0000100517. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000103379 from 2017 to 2024
# Download completed for CIK 0000103379. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000104169 from 2017 to 2024
# Download completed for CIK 0000104169. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000104889 from 2017 to 2024
# Download completed for CIK 0000104889. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000105319 from 2017 to 2024
# Download completed for CIK 0000105319. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000105418 from 2017 to 2024
# Download completed for CIK 0000105418. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000106040 from 2017 to 2024
# Download completed for CIK 0000106040. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000106640 from 2017 to 2024
# Download completed for CIK 0000106640. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000109156 from 2017 to 2024
# Download completed for CIK 0000109156. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000109198 from 2017 to 2024
# Download completed for CIK 0000109198. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000109380 from 2017 to 2024
# Download completed for CIK 0000109380. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000110471 from 2017 to 2024
# Download completed for CIK 0000110471. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000200406 from 2017 to 2024
# Download completed for CIK 0000200406. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000216085 from 2017 to 2024
# Download completed for CIK 0000216085. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000217410 from 2017 to 2024
# Download completed for CIK 0000217410. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000310158 from 2017 to 2024
# Download completed for CIK 0000310158. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000310732 from 2017 to 2024
# Download completed for CIK 0000310732. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000312069 from 2017 to 2024
# Download completed for CIK 0000312069. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000313216 from 2017 to 2024
# Download completed for CIK 0000313216. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000313807 from 2017 to 2024
# Download completed for CIK 0000313807. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000313838 from 2017 to 2024
# Download completed for CIK 0000313838. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000313927 from 2017 to 2024
# Download completed for CIK 0000313927. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000315189 from 2017 to 2024
# Download completed for CIK 0000315189. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000316709 from 2017 to 2024
# Download completed for CIK 0000316709. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000318154 from 2017 to 2024
# Download completed for CIK 0000318154. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000320187 from 2017 to 2024
# Download completed for CIK 0000320187. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000320193 from 2017 to 2024
# Download completed for CIK 0000320193. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000350698 from 2017 to 2024
# Download completed for CIK 0000350698. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000353278 from 2017 to 2024
# Download completed for CIK 0000353278. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000354950 from 2017 to 2024
# Download completed for CIK 0000354950. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000701374 from 2017 to 2024
# Download completed for CIK 0000701374. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000703351 from 2017 to 2024
# Download completed for CIK 0000703351. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000704415 from 2017 to 2024
# Download completed for CIK 0000704415. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0000711404 from 2017 to 2024
# Download completed for CIK 0000711404. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000712515 from 2017 to 2024
# Download completed for CIK 0000712515. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000713676 from 2017 to 2024
# Download completed for CIK 0000713676. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000716643 from 2017 to 2024
# Download completed for CIK 0000716643. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000719955 from 2017 to 2024
# Download completed for CIK 0000719955. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000723612 from 2017 to 2024
# Download completed for CIK 0000723612. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000724571 from 2017 to 2024
# Download completed for CIK 0000724571. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0000726958 from 2017 to 2024
# Download completed for CIK 0000726958. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000731766 from 2017 to 2024
# Download completed for CIK 0000731766. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000732712 from 2017 to 2024
# Download completed for CIK 0000732712. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000732717 from 2017 to 2024
# Download completed for CIK 0000732717. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000745732 from 2017 to 2024
# Download completed for CIK 0000745732. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000759944 from 2017 to 2024
# Download completed for CIK 0000759944. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000764478 from 2017 to 2024
# Download completed for CIK 0000764478. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000766421 from 2017 to 2024
# Download completed for CIK 0000766421. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000768835 from 2017 to 2024
# Download completed for CIK 0000768835. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000769520 from 2017 to 2024
# Download completed for CIK 0000769520. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000789019 from 2017 to 2024
# Download completed for CIK 0000789019. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000789570 from 2017 to 2024
# Download completed for CIK 0000789570. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000791963 from 2017 to 2024
# Download completed for CIK 0000791963. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000793952 from 2017 to 2024
# Download completed for CIK 0000793952. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000794367 from 2017 to 2024
# Download completed for CIK 0000794367. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000796343 from 2017 to 2024
# Download completed for CIK 0000796343. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000797721 from 2017 to 2024
# Download completed for CIK 0000797721. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000800240 from 2017 to 2024
# Download completed for CIK 0000800240. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000800365 from 2017 to 2024
# Download completed for CIK 0000800365. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000800840 from 2017 to 2024
# Download completed for CIK 0000800840. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000800921 from 2017 to 2024
# Download completed for CIK 0000800921. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000804328 from 2017 to 2024
# Download completed for CIK 0000804328. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000806914 from 2017 to 2024
# Download completed for CIK 0000806914. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000807707 from 2017 to 2024
# Download completed for CIK 0000807707. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000807882 from 2017 to 2024
# Download completed for CIK 0000807882. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000813762 from 2017 to 2024
# Download completed for CIK 0000813762. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000813828 from 2017 to 2024
# Download completed for CIK 0000813828. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000814453 from 2017 to 2024
# Download completed for CIK 0000814453. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000821002 from 2017 to 2024
# Download completed for CIK 0000821002. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000821130 from 2017 to 2024
# Download completed for CIK 0000821130. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000824046 from 2017 to 2024
# Download completed for CIK 0000824046. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000825542 from 2017 to 2024
# Download completed for CIK 0000825542. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000827187 from 2017 to 2024
# Download completed for CIK 0000827187. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000829224 from 2017 to 2024
# Download completed for CIK 0000829224. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000831001 from 2017 to 2024
# Download completed for CIK 0000831001. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000842180 from 2017 to 2024
# Download completed for CIK 0000842180. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000849399 from 2017 to 2024
# Download completed for CIK 0000849399. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000850209 from 2017 to 2024
# Download completed for CIK 0000850209. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000852772 from 2017 to 2024
# Download completed for CIK 0000852772. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000852937 from 2017 to 2024
# Download completed for CIK 0000852937. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000854499 from 2017 to 2024
# Download completed for CIK 0000854499. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000857737 from 2017 to 2024
# Download completed for CIK 0000857737. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0000858339 from 2017 to 2024
# Download completed for CIK 0000858339. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0000858446 from 2017 to 2024
# Download completed for CIK 0000858446. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000865752 from 2017 to 2024
# Download completed for CIK 0000865752. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000866787 from 2017 to 2024
# Download completed for CIK 0000866787. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000870016 from 2017 to 2024
# Download completed for CIK 0000870016. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000872589 from 2017 to 2024
# Download completed for CIK 0000872589. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000874766 from 2017 to 2024
# Download completed for CIK 0000874766. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000877890 from 2017 to 2024
# Download completed for CIK 0000877890. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0000882095 from 2017 to 2024
# Download completed for CIK 0000882095. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000883569 from 2017 to 2024
# Download completed for CIK 0000883569. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000883943 from 2017 to 2024
# Download completed for CIK 0000883943. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0000884217 from 2017 to 2024
# Download completed for CIK 0000884217. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0000884940 from 2017 to 2024
# Download completed for CIK 0000884940. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0000885245 from 2017 to 2024
# Download completed for CIK 0000885245. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000885639 from 2017 to 2024
# Download completed for CIK 0000885639. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000886158 from 2017 to 2024
# Download completed for CIK 0000886158. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0000886982 from 2017 to 2024
# Download completed for CIK 0000886982. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000887596 from 2017 to 2024
# Download completed for CIK 0000887596. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000889131 from 2017 to 2024
# Download completed for CIK 0000889131. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000890491 from 2017 to 2024
# Download completed for CIK 0000890491. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0000895421 from 2017 to 2024
# Download completed for CIK 0000895421. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000895447 from 2017 to 2024
# Download completed for CIK 0000895447. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000896878 from 2017 to 2024
# Download completed for CIK 0000896878. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000897429 from 2017 to 2024
# Download completed for CIK 0000897429. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0000898173 from 2017 to 2024
# Download completed for CIK 0000898173. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000899051 from 2017 to 2024
# Download completed for CIK 0000899051. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000899715 from 2017 to 2024
# Download completed for CIK 0000899715. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000901491 from 2017 to 2024
# Download completed for CIK 0000901491. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000901832 from 2017 to 2024
# Download completed for CIK 0000901832. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000906553 from 2017 to 2024
# Download completed for CIK 0000906553. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000908937 from 2017 to 2024
# Download completed for CIK 0000908937. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000909832 from 2017 to 2024
# Download completed for CIK 0000909832. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000910406 from 2017 to 2024
# Download completed for CIK 0000910406. Number of filings downloaded: 9
# Downloading 10-K filings for CIK 0000910521 from 2017 to 2024
# Download completed for CIK 0000910521. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000912615 from 2017 to 2024
# Download completed for CIK 0000912615. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000913241 from 2017 to 2024
# Download completed for CIK 0000913241. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000916365 from 2017 to 2024
# Download completed for CIK 0000916365. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000919012 from 2017 to 2024
# Download completed for CIK 0000919012. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000924613 from 2017 to 2024
# Download completed for CIK 0000924613. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0000927628 from 2017 to 2024
# Download completed for CIK 0000927628. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000931015 from 2017 to 2024
# Download completed for CIK 0000931015. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000935703 from 2017 to 2024
# Download completed for CIK 0000935703. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000940944 from 2017 to 2024
# Download completed for CIK 0000940944. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000945114 from 2017 to 2024
# Download completed for CIK 0000945114. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0000949870 from 2017 to 2024
# Download completed for CIK 0000949870. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001001082 from 2017 to 2024
# Download completed for CIK 0001001082. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001001250 from 2017 to 2024
# Download completed for CIK 0001001250. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001003811 from 2017 to 2024
# Download completed for CIK 0001003811. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001008654 from 2017 to 2024
# Download completed for CIK 0001008654. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001013488 from 2017 to 2024
# Download completed for CIK 0001013488. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001015780 from 2017 to 2024
# Download completed for CIK 0001015780. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001017480 from 2017 to 2024
# Download completed for CIK 0001017480. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001018724 from 2017 to 2024
# Download completed for CIK 0001018724. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001018840 from 2017 to 2024
# Download completed for CIK 0001018840. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001020859 from 2017 to 2024
# Download completed for CIK 0001020859. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001021270 from 2017 to 2024
# Download completed for CIK 0001021270. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001024305 from 2017 to 2024
# Download completed for CIK 0001024305. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001035002 from 2017 to 2024
# Download completed for CIK 0001035002. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001037038 from 2017 to 2024
# Download completed for CIK 0001037038. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001041061 from 2017 to 2024
# Download completed for CIK 0001041061. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001041859 from 2017 to 2024
# Download completed for CIK 0001041859. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001045810 from 2017 to 2024
# Download completed for CIK 0001045810. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001046311 from 2017 to 2024
# Download completed for CIK 0001046311. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001048286 from 2017 to 2024
# Download completed for CIK 0001048286. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001048515 from 2017 to 2024
# Download completed for CIK 0001048515. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001050797 from 2017 to 2024
# Download completed for CIK 0001050797. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001058090 from 2017 to 2024
# Download completed for CIK 0001058090. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001059272 from 2017 to 2024
# Download completed for CIK 0001059272. Number of filings downloaded: 1
# Downloading 10-K filings for CIK 0001060822 from 2017 to 2024
# Download completed for CIK 0001060822. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001065088 from 2017 to 2024
# Download completed for CIK 0001065088. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001065280 from 2017 to 2024
# Download completed for CIK 0001065280. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001065837 from 2017 to 2024
# Download completed for CIK 0001065837. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001067294 from 2017 to 2024
# Download completed for CIK 0001067294. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001067983 from 2017 to 2024
# Download completed for CIK 0001067983. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001069202 from 2017 to 2024
# Download completed for CIK 0001069202. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001071255 from 2017 to 2024
# Download completed for CIK 0001071255. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001075531 from 2017 to 2024
# Download completed for CIK 0001075531. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001078207 from 2017 to 2024
# Download completed for CIK 0001078207. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001083522 from 2017 to 2024
# Download completed for CIK 0001083522. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001089063 from 2017 to 2024
# Download completed for CIK 0001089063. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001089113 from 2017 to 2024
# Download completed for CIK 0001089113. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001091667 from 2017 to 2024
# Download completed for CIK 0001091667. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001096752 from 2017 to 2024
# Download completed for CIK 0001096752. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001097149 from 2017 to 2024
# Download completed for CIK 0001097149. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001099219 from 2017 to 2024
# Download completed for CIK 0001099219. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001103982 from 2017 to 2024
# Download completed for CIK 0001103982. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001107280 from 2017 to 2024
# Download completed for CIK 0001107280. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001113169 from 2017 to 2024
# Download completed for CIK 0001113169. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001113809 from 2017 to 2024
# Download completed for CIK 0001113809. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001114448 from 2017 to 2024
# Download completed for CIK 0001114448. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001116132 from 2017 to 2024
# Download completed for CIK 0001116132. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001121404 from 2017 to 2024
# Download completed for CIK 0001121404. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001131399 from 2017 to 2024
# Download completed for CIK 0001131399. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001132979 from 2017 to 2024
# Download completed for CIK 0001132979. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001133311 from 2017 to 2024
# Download completed for CIK 0001133311. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001137774 from 2017 to 2024
# Download completed for CIK 0001137774. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001141391 from 2017 to 2024
# Download completed for CIK 0001141391. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001144145 from 2017 to 2024
# Download completed for CIK 0001144145. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001156039 from 2017 to 2024
# Download completed for CIK 0001156039. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001156388 from 2017 to 2024
# Download completed for CIK 0001156388. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001158449 from 2017 to 2024
# Download completed for CIK 0001158449. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001158463 from 2017 to 2024
# Download completed for CIK 0001158463. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001159167 from 2017 to 2024
# Download completed for CIK 0001159167. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001161154 from 2017 to 2024
# Download completed for CIK 0001161154. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001163165 from 2017 to 2024
# Download completed for CIK 0001163165. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001166691 from 2017 to 2024
# Download completed for CIK 0001166691. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001170010 from 2017 to 2024
# Download completed for CIK 0001170010. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001171759 from 2017 to 2024
# Download completed for CIK 0001171759. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001172222 from 2017 to 2024
# Download completed for CIK 0001172222. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001173431 from 2017 to 2024
# Download completed for CIK 0001173431. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001174922 from 2017 to 2024
# Download completed for CIK 0001174922. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001176948 from 2017 to 2024
# Download completed for CIK 0001176948. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001195734 from 2017 to 2024
# Download completed for CIK 0001195734. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001206264 from 2017 to 2024
# Error occurred while downloading filing for accession number {}: {} 0001206264-19-000047 ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Download completed for CIK 0001206264. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001211351 from 2017 to 2024
# Download completed for CIK 0001211351. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001223389 from 2017 to 2024
# Download completed for CIK 0001223389. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001261333 from 2017 to 2024
# Download completed for CIK 0001261333. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001271075 from 2017 to 2024
# Download completed for CIK 0001271075. Number of filings downloaded: 2
# Downloading 10-K filings for CIK 0001273931 from 2017 to 2024
# Download completed for CIK 0001273931. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001278027 from 2017 to 2024
# Download completed for CIK 0001278027. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001281761 from 2017 to 2024
# Download completed for CIK 0001281761. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001283699 from 2017 to 2024
# Download completed for CIK 0001283699. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001286139 from 2017 to 2024
# Download completed for CIK 0001286139. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001286681 from 2017 to 2024
# Download completed for CIK 0001286681. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001289460 from 2017 to 2024
# Download completed for CIK 0001289460. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001295401 from 2017 to 2024
# Download completed for CIK 0001295401. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001295947 from 2017 to 2024
# Download completed for CIK 0001295947. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001299709 from 2017 to 2024
# Download completed for CIK 0001299709. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001300514 from 2017 to 2024
# Download completed for CIK 0001300514. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001308547 from 2017 to 2024
# Download completed for CIK 0001308547. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001310067 from 2017 to 2024
# Download completed for CIK 0001310067. Number of filings downloaded: 2
# Downloading 10-K filings for CIK 0001314727 from 2017 to 2024
# Download completed for CIK 0001314727. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001318008 from 2017 to 2024
# Download completed for CIK 0001318008. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001318484 from 2017 to 2024
# Download completed for CIK 0001318484. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001318605 from 2017 to 2024
# Download completed for CIK 0001318605. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001319947 from 2017 to 2024
# Download completed for CIK 0001319947. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001324424 from 2017 to 2024
# Download completed for CIK 0001324424. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001326380 from 2017 to 2024
# Download completed for CIK 0001326380. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001326801 from 2017 to 2024
# Download completed for CIK 0001326801. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001331875 from 2017 to 2024
# Download completed for CIK 0001331875. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001333493 from 2017 to 2024
# Download completed for CIK 0001333493. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001333986 from 2017 to 2024
# Download completed for CIK 0001333986. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001334036 from 2017 to 2024
# Download completed for CIK 0001334036. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001335258 from 2017 to 2024
# Download completed for CIK 0001335258. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001336216 from 2017 to 2024
# Download completed for CIK 0001336216. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001336917 from 2017 to 2024
# Download completed for CIK 0001336917. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001341439 from 2017 to 2024
# Download completed for CIK 0001341439. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001341766 from 2017 to 2024
# Download completed for CIK 0001341766. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001345016 from 2017 to 2024
# Download completed for CIK 0001345016. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001357204 from 2017 to 2024
# Download completed for CIK 0001357204. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001359841 from 2017 to 2024
# Download completed for CIK 0001359841. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001361658 from 2017 to 2024
# Download completed for CIK 0001361658. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001362468 from 2017 to 2024
# Download completed for CIK 0001362468. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001365038 from 2017 to 2024
# Download completed for CIK 0001365038. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001365135 from 2017 to 2024
# Download completed for CIK 0001365135. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001366561 from 2017 to 2024
# Download completed for CIK 0001366561. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001368458 from 2017 to 2024
# Download completed for CIK 0001368458. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001370637 from 2017 to 2024
# Download completed for CIK 0001370637. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001371285 from 2017 to 2024
# Download completed for CIK 0001371285. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001382821 from 2017 to 2024
# Download completed for CIK 0001382821. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001384905 from 2017 to 2024
# Download completed for CIK 0001384905. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001390777 from 2017 to 2024
# Download completed for CIK 0001390777. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001393612 from 2017 to 2024
# Download completed for CIK 0001393612. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001393818 from 2017 to 2024
# Download completed for CIK 0001393818. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001393883 from 2017 to 2024
# Download completed for CIK 0001393883. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001396033 from 2017 to 2024
# Download completed for CIK 0001396033. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001397187 from 2017 to 2024
# Download completed for CIK 0001397187. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001400891 from 2017 to 2024
# Download completed for CIK 0001400891. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001402057 from 2017 to 2024
# ...
# Downloading 10-K filings for CIK 0001467858 from 2017 to 2024
# Download completed for CIK 0001467858. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001468174 from 2017 to 2024
# Download completed for CIK 0001468174. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001468327 from 2017 to 2024
# Download completed for CIK 0001468327. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001471055 from 2017 to 2024
# Download completed for CIK 0001471055. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001475115 from 2017 to 2024
# Download completed for CIK 0001475115. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001477449 from 2017 to 2024
# Download completed for CIK 0001477449. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001490281 from 2017 to 2024
# Download completed for CIK 0001490281. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001494259 from 2017 to 2024
# Download completed for CIK 0001494259. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001496963 from 2017 to 2024
# Download completed for CIK 0001496963. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001498710 from 2017 to 2024
# Download completed for CIK 0001498710. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001502034 from 2017 to 2024
# Download completed for CIK 0001502034. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001504776 from 2017 to 2024
# Download completed for CIK 0001504776. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001507079 from 2017 to 2024
# Download completed for CIK 0001507079. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001510295 from 2017 to 2024
# Download completed for CIK 0001510295. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001512673 from 2017 to 2024
# Download completed for CIK 0001512673. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001514991 from 2017 to 2024
# Download completed for CIK 0001514991. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001519751 from 2017 to 2024
# Download completed for CIK 0001519751. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001524358 from 2017 to 2024
# Download completed for CIK 0001524358. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001525769 from 2017 to 2024
# Download completed for CIK 0001525769. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001526520 from 2017 to 2024
# Download completed for CIK 0001526520. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001528849 from 2017 to 2024
# Download completed for CIK 0001528849. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001528930 from 2017 to 2024
# Download completed for CIK 0001528930. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001530721 from 2017 to 2024
# Download completed for CIK 0001530721. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001530950 from 2017 to 2024
# Download completed for CIK 0001530950. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001531152 from 2017 to 2024
# Download completed for CIK 0001531152. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001534701 from 2017 to 2024
# Download completed for CIK 0001534701. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001534992 from 2017 to 2024
# Download completed for CIK 0001534992. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001535929 from 2017 to 2024
# Download completed for CIK 0001535929. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001543151 from 2017 to 2024
# Download completed for CIK 0001543151. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001546417 from 2017 to 2024
# Download completed for CIK 0001546417. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001547459 from 2017 to 2024
# Download completed for CIK 0001547459. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001551152 from 2017 to 2024
# Download completed for CIK 0001551152. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001552033 from 2017 to 2024
# Download completed for CIK 0001552033. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001559720 from 2017 to 2024
# Download completed for CIK 0001559720. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001564408 from 2017 to 2024
# Download completed for CIK 0001564408. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001564708 from 2017 to 2024
# Download completed for CIK 0001564708. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001564822 from 2017 to 2024
# Download completed for CIK 0001564822. Number of filings downloaded: 2
# Downloading 10-K filings for CIK 0001564902 from 2017 to 2024
# Download completed for CIK 0001564902. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001571996 from 2017 to 2024
# Download completed for CIK 0001571996. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001575189 from 2017 to 2024
# Download completed for CIK 0001575189. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001575515 from 2017 to 2024
# Download completed for CIK 0001575515. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001576942 from 2017 to 2024
# Download completed for CIK 0001576942. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001579298 from 2017 to 2024
# Download completed for CIK 0001579298. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001580864 from 2017 to 2024
# Download completed for CIK 0001580864. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001585521 from 2017 to 2024
# Download completed for CIK 0001585521. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001585689 from 2017 to 2024
# Download completed for CIK 0001585689. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001592058 from 2017 to 2024
# Download completed for CIK 0001592058. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001593538 from 2017 to 2024
# Download completed for CIK 0001593538. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001594109 from 2017 to 2024
# Download completed for CIK 0001594109. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001594805 from 2017 to 2024
# Download completed for CIK 0001594805. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001598674 from 2017 to 2024
# Download completed for CIK 0001598674. Number of filings downloaded: 2
# Downloading 10-K filings for CIK 0001600033 from 2017 to 2024
# Download completed for CIK 0001600033. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001601712 from 2017 to 2024
# Download completed for CIK 0001601712. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001606366 from 2017 to 2024
# Download completed for CIK 0001606366. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001609711 from 2017 to 2024
# Download completed for CIK 0001609711. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001610520 from 2017 to 2024
# Download completed for CIK 0001610520. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001616707 from 2017 to 2024
# Download completed for CIK 0001616707. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001617553 from 2017 to 2024
# Download completed for CIK 0001617553. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001618756 from 2017 to 2024
# Download completed for CIK 0001618756. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001618921 from 2017 to 2024
# Download completed for CIK 0001618921. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001632790 from 2017 to 2024
# Download completed for CIK 0001632790. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001633917 from 2017 to 2024
# Download completed for CIK 0001633917. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001634117 from 2017 to 2024
# Download completed for CIK 0001634117. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001635327 from 2017 to 2024
# Download completed for CIK 0001635327. Number of filings downloaded: 1
# Downloading 10-K filings for CIK 0001636222 from 2017 to 2024
# Download completed for CIK 0001636222. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001637207 from 2017 to 2024
# Download completed for CIK 0001637207. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001637459 from 2017 to 2024
# Download completed for CIK 0001637459. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001639825 from 2017 to 2024
# Download completed for CIK 0001639825. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001643953 from 2017 to 2024
# Download completed for CIK 0001643953. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001644406 from 2017 to 2024
# Download completed for CIK 0001644406. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001649744 from 2017 to 2024
# Download completed for CIK 0001649744. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001652044 from 2017 to 2024
# Download completed for CIK 0001652044. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001653653 from 2017 to 2024
# Download completed for CIK 0001653653. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001655210 from 2017 to 2024
# Download completed for CIK 0001655210. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001662579 from 2017 to 2024
# Download completed for CIK 0001662579. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001668717 from 2017 to 2024
# Download completed for CIK 0001668717. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001669779 from 2017 to 2024
# Download completed for CIK 0001669779. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001674910 from 2017 to 2024
# Download completed for CIK 0001674910. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001679788 from 2017 to 2024
# Download completed for CIK 0001679788. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001682852 from 2017 to 2024
# Download completed for CIK 0001682852. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001683606 from 2017 to 2024
# Download completed for CIK 0001683606. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001683825 from 2017 to 2024
# Download completed for CIK 0001683825. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001685040 from 2017 to 2024
# Download completed for CIK 0001685040. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001690820 from 2017 to 2024
# Download completed for CIK 0001690820. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001701114 from 2017 to 2024
# Download completed for CIK 0001701114. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001702744 from 2017 to 2024
# Download completed for CIK 0001702744. Number of filings downloaded: 8
# Downloading 10-K filings for CIK 0001702780 from 2017 to 2024
# Download completed for CIK 0001702780. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001703056 from 2017 to 2024
# Download completed for CIK 0001703056. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001705110 from 2017 to 2024
# Download completed for CIK 0001705110. Number of filings downloaded: 7
# Downloading 10-K filings for CIK 0001705338 from 2017 to 2024
# Download completed for CIK 0001705338. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001726173 from 2017 to 2024
# Download completed for CIK 0001726173. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001739940 from 2017 to 2024
# Download completed for CIK 0001739940. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001744489 from 2017 to 2024
# Download completed for CIK 0001744489. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001754301 from 2017 to 2024
# Download completed for CIK 0001754301. Number of filings downloaded: 6
# Downloading 10-K filings for CIK 0001759008 from 2017 to 2024
# Download completed for CIK 0001759008. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001759509 from 2017 to 2024
# Download completed for CIK 0001759509. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001760965 from 2017 to 2024
# Download completed for CIK 0001760965. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001766502 from 2017 to 2024
# Download completed for CIK 0001766502. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001775625 from 2017 to 2024
# Download completed for CIK 0001775625. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001776967 from 2017 to 2024
# Download completed for CIK 0001776967. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001786431 from 2017 to 2024
# Download completed for CIK 0001786431. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001800227 from 2017 to 2024
# Download completed for CIK 0001800227. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001818874 from 2017 to 2024
# Download completed for CIK 0001818874. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001820953 from 2017 to 2024
# Download completed for CIK 0001820953. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001821806 from 2017 to 2024
# Download completed for CIK 0001821806. Number of filings downloaded: 5
# Downloading 10-K filings for CIK 0001828105 from 2017 to 2024
# Download completed for CIK 0001828105. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001828108 from 2017 to 2024
# Download completed for CIK 0001828108. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001831631 from 2017 to 2024
# Download completed for CIK 0001831631. Number of filings downloaded: 4
# Downloading 10-K filings for CIK 0001854139 from 2017 to 2024
# Download completed for CIK 0001854139. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001856236 from 2017 to 2024
# Download completed for CIK 0001856236. Number of filings downloaded: 3
# Downloading 10-K filings for CIK 0001858681 from 2017 to 2024
# Download completed for CIK 0001858681. Number of filings downloaded: 2
# Downloading 10-K filings for CIK 0001883685 from 2017 to 2024
# Download completed for CIK 0001883685. Number of filings downloaded: 2
# Downloading 10-K filings for CIK 0001884697 from 2017 to 2024
# Download completed for CIK 0001884697. Number of filings downloaded: 1
# Downloading 10-K filings for CIK 0001898795 from 2017 to 2024
# Download completed for CIK 0001898795. Number of filings downloaded: 2
# Downloading 10-K filings for CIK 0001971213 from 2017 to 2024
# Download completed for CIK 0001971213. Number of filings downloaded: 1
# Downloading 10-K filings for CIK 0001995807 from 2017 to 2024
# Download completed for CIK 0001995807. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0001999001 from 2017 to 2024
# Download completed for CIK 0001999001. Number of filings downloaded: 0
# Downloading 10-K filings for CIK 0002012383 from 2017 to 2024
# Download completed for CIK 0002012383. Number of filings downloaded: 0
#
# --- Download Summary ---
# Finished downloading 10-K HTML filings.
# Total filings downloaded: 3221
# Files are saved in c:\Users\kalagat23\Desktop\Tejaswi_PhD\Year 2\VA_VC\10k_html_filings_2017_2024
#
# All CIKs processed successfully (though some may not have had filings in the period).
